# %%
import os
import re
from os.path import exists
import pandas as pd
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
import decimal
plt.style.use('seaborn-whitegrid')

# turn csv string to numbers
def fixFormat(df):
    df = df.drop( df[df['Repeat']=='Repeat'].index )
    
    if 'Repeat' in df.columns:
        df["Repeat"] = df["Repeat"].astype(int)
    if 'Generation' in df.columns:
        df["Generation"] = df["Generation"].astype(int)
    if 'FitnessEvaluateCountReachTarget' in df.columns:
        df["FitnessEvaluateCountReachTarget"] = df["FitnessEvaluateCountReachTarget"].astype(int)
    
    if 'F(x)' in df.columns:
        df["F(x)"] = df["F(x)"].astype(float)
        if wantFitness is False:
            df["F(x)"] = -df["F(x)"]
    
    if df.shape[1] > 3:
        for i in range(df.shape[1]-2):
            df.iloc[:,i+2] = df.iloc[:,i+2].astype(float)
    return df

# get set of crossovers and benchmarks from folder
def getLists(files):
    crossovers = set()
    benchmarks = set()
    for file in files:
        crossovers.add(file.split("+")[0])
        benchmarks.add(file.split("+")[1].split(".")[0])
    return crossovers, benchmarks

#  showPlot(file, df, "Generation", "F(x)")
def showPlot(file, df, x, y):
    print(file)
    plt.plot(df["Generation"], df["F(x)"], 'o', color='black')
    plt.show()
    
def titleFixer(string,target_id):
    return string.replace("HyperEllipsoid","Hyper-Ellipsoid").replace("DixonPrice","Dixon-Price").replace("Bi_Rastrigin","Bi_rastrigin")

# %%
# folders = ["FrontRearCrossover", "HighDimensionalGeneticAlgorithmToolboxCrossover","RingCrossover", "CollectiveCrossover"]
# stats = ["mean", "max", "min", "var", "sum", "maxFitnessCount"]
target_id = 2
target = [
    {
#         , "max"
        "folder": "RingCrossover/corrected=true/randomSeed=1", "stats": ["mean", "min", "max"], "wantFitness": False, 
        "oriResult": getRingCrossoverOriResult("RingCrossover/corrected=false/randomSeed=1"), "index": {'max':'Worst', "mean": "Average", "min": "Best"},
        "crossoverFunctionRename": {"P1XO": "SinglePointCrossover", "P2XO": "TwoPointCrossover"},
        "crossoverFunctionNameSpacer": r"(?<=\w)([A-Z])",
        "benchmarkFunctionNameSpacer": r"(?<=\w)([A-Z])",
    },
    {
        "folder": "HighDimensionalGeneticAlgorithmToolboxCrossover/bit=8/randomSeed=1", "stats": ["mean", "min", "var"], "wantFitness": False, 
        "oriResult": getHDGAOriResult("HighDimensionalGeneticAlgorithmToolboxCrossover/bit=8/randomSeed=1"), 
        "index": {'mean':'Mean', "min": "Min", "var": "Variance"},
        "crossoverFunctionRename": {"P1XO": "SinglePointCrossover", "HighDimensionalGeneticAlgorithmToolboxCrossover": "HDGAToolboxCrossover"},
        "crossoverFunctionNameSpacer": r"(?<=\w)([A-Z][^HDGAT])",
        "benchmarkFunctionNameSpacer": r"(?<=\w)([A-Z])",
    },
    {
        "folder": "CollectiveCrossover/randomSeed=1", "stats": ["mean"], "wantFitness": False, 
        "oriResult": getCollectiveCrossoverOriResult("CollectiveCrossover/randomSeed=1"),  "index": {'mean':'Mean'},
        "crossoverFunctionRename": {"P1XO-30": "SinglePointCrossover-30", "P1XO-50": "SinglePointCrossover-50",
                             "P2XO-30": "TwoPointCrossover-30", "P2XO-50": "TwoPointCrossover-50"},
        "crossoverFunctionNameSpacer": r"(?<=\w)([A-Z])",
        "benchmarkFunctionNameSpacer": r"(?<=\w)((and)|([A-Z]))",
    },
]

folder = target[target_id]["folder"]
stats = target[target_id]["stats"]
wantFitness = target[target_id]["wantFitness"]
oriResult = target[target_id]["oriResult"]
index = target[target_id]["index"]
crossoverFunctionRename=target[target_id]["crossoverFunctionRename"]
crossoverFunctionNameSpacer=target[target_id]["crossoverFunctionNameSpacer"]
benchmarkFunctionNameSpacer=target[target_id]["benchmarkFunctionNameSpacer"]

def compareResultBetweenCrossover(df, crossover1, crossover2, stat):
    crossover1_win = 0
    crossover1_tie = 0
    for column in result.columns:
        if result.loc[crossover1, stat][column] < result.loc[crossover2, stat][column]:
            crossover1_win = crossover1_win + 1
        elif result.loc[crossover1, stat][column] == result.loc[crossover2, stat][column]:
            crossover1_tie = crossover1_tie + 1
            print(column)
    return crossover1_win, crossover1_tie, len(result.columns) - crossover1_win - crossover1_tie
    
# process file not have FitnessEvaluateCountReachTarget in file name
for subdir, dirs, files in os.walk(folder):
    crossovers, benchmarks = getLists(files)
    print(crossovers)
    print(benchmarks)
    iterables = [crossovers, stats]
    result = pd.DataFrame(columns = benchmarks, index = pd.MultiIndex.from_product(iterables, names=["crossover", "stat"]))
    files = [file for file in files if 'FitnessEvaluateCountReachTarget' not in file]
    for file in files:
        crossover = file.split("+")[0]
        benchmark = file.split("+")[1].split(".")[0]
        df = pd.read_csv(folder+"/"+file, index_col=False)
        df = fixFormat(df)

        temp_result = {}
        temp_df = df.groupby("Generation")["F(x)"]
        temp_result["mean"] = temp_df.mean()[df["Generation"].max()]
        temp_result["max"] = temp_df.max()[df["Generation"].max()]
        temp_result["min"] = temp_df.min()[df["Generation"].max()]
        temp_result["var"] = temp_df.var()[df["Generation"].max()]
        temp_result["sum"] = temp_df.sum()[df["Generation"].max()]

#         if "AxisParallelHyperEllipsoidObjective" in file:
#         print(file)
#         for_graph = df.groupby(['Generation']).mean()["F(x)"]
#         plt.plot(for_graph.index, for_graph)
#         plt.show()
#         plt.plot(df['Generation'], df['F(x)'], 'o')
#         plt.show()
#         plt.plot(for_graph.mean()["F(x)"],index, for_graph.mean()["F(x)"])
#         plt.scatter(df["Generation"], df["F(x)"])
#         plt.show()
        for stat in stats:
            if stat in temp_result.keys():
                result.loc[crossover, stat][benchmark] = temp_result[stat]
        
    filtered_row_index = [oriResult.index.get_level_values(0)]
#     filter row that contain certain string in original result (e.x: filter row that is not 30 dimension)
#     filtered_row_index = [k for k in oriResult.index.get_level_values(0).tolist() if '30' in k]
    for column in result.columns:
        fig, axes = plt.subplots(1, 2)
        # filter unrelated stat, rename to paper's stat (max -> Best...)
        a = oriResult[column][np.in1d(oriResult.index.get_level_values(1), stats)].rename(index=index, level=1)
        a = a[np.in1d(a.index.get_level_values(0), filtered_row_index)].rename(index=index, level=1).rename(crossoverFunctionRename).rename(lambda s: re.sub(crossoverFunctionNameSpacer, r" \1",s))
        a = a.unstack().plot(kind='bar', title='Original result of\n'+re.sub(benchmarkFunctionNameSpacer, r" \1",titleFixer(column.replace("Objective", "Function"),target_id)), ax=axes[0],figsize=(14,4.8))
        a.set_ylabel("Fitness value" if wantFitness else "f(x)")
        plt.setp(axes[0].get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
        b = result[column].rename(index=index, level=1).rename(crossoverFunctionRename).rename(lambda s: re.sub(crossoverFunctionNameSpacer, r" \1",s))
        b = b.unstack().plot(kind='bar', title='Reproduce result of\n'+re.sub(benchmarkFunctionNameSpacer, r" \1",titleFixer(column.replace("Objective", "Function"),target_id)), ax=axes[1])
        plt.setp(axes[1].get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
#         plt.savefig(column + ".jpg", bbox_inches='tight')
#     print(oriResult)
    plt.show()
    print(result.transpose())
#         win, tie, lose = compareResultBetweenCrossover(df, "CollectiveCrossover-30", "P1XO-30", "mean")
#         print(str(win) + " : " + str(tie) + " : " + str(lose))
#         win, tie, lose = compareResultBetweenCrossover(df, "CollectiveCrossover-30", "P2XO-30", "mean")
#         print(str(win) + " : " + str(tie) + " : " + str(lose))
# Out:
# {'P1XO-50', 'P2XO-50', 'P2XO-30', 'CollectiveCrossover-50', 'P1XO-30', 'CollectiveCrossover-30'}
# {'ShiftedandRotatedRastriginObjective', 'ShiftedandRotatedBentCigarObjective', 'ShiftedandRotatedRosenbrockObjective', 'ShiftedandRotatedLevyObjective', 'ShiftedandRotatedZakharovObjective', 'ShiftedandRotatedSchwefelObjective', 'ShiftedandRotatedLunacekBi_RastriginObjective'}
# crossover                                                 P1XO-50  \
# stat                                                         mean
# ShiftedandRotatedRastriginObjective                    1254.47394
# ShiftedandRotatedBentCigarObjective            99744839295.118744
# ShiftedandRotatedRosenbrockObjective                 23103.056799
# ShiftedandRotatedLevyObjective                       42233.532893
# ShiftedandRotatedZakharovObjective               518076933.930404
# ShiftedandRotatedSchwefelObjective                    17042.32426
# ShiftedandRotatedLunacekBi_RastriginObjective         3788.963815
#
# crossover                                                 P2XO-50  \
# stat                                                         mean
# ShiftedandRotatedRastriginObjective                   1239.041198
# ShiftedandRotatedBentCigarObjective            99480511400.970352
# ShiftedandRotatedRosenbrockObjective                 22657.172432
# ShiftedandRotatedLevyObjective                       41498.871054
# ShiftedandRotatedZakharovObjective               219143763.693902
# ShiftedandRotatedSchwefelObjective                   17078.388078
# ShiftedandRotatedLunacekBi_RastriginObjective         3662.830163
#
# crossover                                                 P2XO-30  \
# stat                                                         mean
# ShiftedandRotatedRastriginObjective                    879.575737
# ShiftedandRotatedBentCigarObjective            38880853022.901909
# ShiftedandRotatedRosenbrockObjective                  8569.660751
# ShiftedandRotatedLevyObjective                       15249.240249
# ShiftedandRotatedZakharovObjective                16658198.138837
# ShiftedandRotatedSchwefelObjective                    9629.191171
# ShiftedandRotatedLunacekBi_RastriginObjective         1957.561436
#
# crossover                                     CollectiveCrossover-50  \
# stat                                                            mean
# ShiftedandRotatedRastriginObjective                       669.209052
# ShiftedandRotatedBentCigarObjective                1532056793.702862
# ShiftedandRotatedRosenbrockObjective                      763.746495
# ShiftedandRotatedLevyObjective                           1585.561569
# ShiftedandRotatedZakharovObjective                      183179.01103
# ShiftedandRotatedSchwefelObjective                        9650.53828
# ShiftedandRotatedLunacekBi_RastriginObjective            1054.628755
#
# crossover                                                 P1XO-30  \
# stat                                                         mean
# ShiftedandRotatedRastriginObjective                    887.053985
# ShiftedandRotatedBentCigarObjective            37728978624.471268
# ShiftedandRotatedRosenbrockObjective                  8445.168868
# ShiftedandRotatedLevyObjective                        16691.72544
# ShiftedandRotatedZakharovObjective                40049880.995254
# ShiftedandRotatedSchwefelObjective                    9605.147752
# ShiftedandRotatedLunacekBi_RastriginObjective         1969.453742
#
# crossover                                     CollectiveCrossover-30
# stat                                                            mean
# ShiftedandRotatedRastriginObjective                       574.798798
# ShiftedandRotatedBentCigarObjective                  165193403.87622
# ShiftedandRotatedRosenbrockObjective                      561.169636
# ShiftedandRotatedLevyObjective                           1033.215446
# ShiftedandRotatedZakharovObjective                      46050.239134
# ShiftedandRotatedSchwefelObjective                        4858.86756
# ShiftedandRotatedLunacekBi_RastriginObjective             863.866444
# {'P1XO-30', 'P2XO-30', 'CollectiveCrossover-30'}
# {'ShiftedandRotatedRastriginObjective', 'ShiftedandRotatedBentCigarObjective', 'ShiftedandRotatedRosenbrockObjective', 'ShiftedandRotatedLevyObjective', 'ShiftedandRotatedZakharovObjective', 'ShiftedandRotatedSchwefelObjective', 'ShiftedandRotatedLunacekBi_RastriginObjective'}
# crossover                                                 P1XO-30  \
# stat                                                         mean
# ShiftedandRotatedRastriginObjective                    887.053985
# ShiftedandRotatedBentCigarObjective            37728978624.471268
# ShiftedandRotatedRosenbrockObjective                  8445.168868
# ShiftedandRotatedLevyObjective                        16691.72544
# ShiftedandRotatedZakharovObjective                40049880.995254
# ShiftedandRotatedSchwefelObjective                    9605.147752
# ShiftedandRotatedLunacekBi_RastriginObjective         1969.453742
#
# crossover                                                 P2XO-30  \
# stat                                                         mean
# ShiftedandRotatedRastriginObjective                    879.575737
# ShiftedandRotatedBentCigarObjective            38880853022.901909
# ShiftedandRotatedRosenbrockObjective                  8569.660751
# ShiftedandRotatedLevyObjective                       15249.240249
# ShiftedandRotatedZakharovObjective                16658198.138837
# ShiftedandRotatedSchwefelObjective                    9629.191171
# ShiftedandRotatedLunacekBi_RastriginObjective         1957.561436
#
# crossover                                     CollectiveCrossover-30
# stat                                                            mean
# ShiftedandRotatedRastriginObjective                       574.798798
# ShiftedandRotatedBentCigarObjective                  165193403.87622
# ShiftedandRotatedRosenbrockObjective                      561.169636
# ShiftedandRotatedLevyObjective                           1033.215446
# ShiftedandRotatedZakharovObjective                      46050.239134
# ShiftedandRotatedSchwefelObjective                        4858.86756
# ShiftedandRotatedLunacekBi_RastriginObjective             863.866444
# {'P1XO-30', 'P2XO-30', 'CollectiveCrossover-30'}
# {'ShiftedandRotatedRastriginObjective', 'ShiftedandRotatedBentCigarObjective', 'ShiftedandRotatedRosenbrockObjective', 'ShiftedandRotatedLevyObjective', 'ShiftedandRotatedZakharovObjective', 'ShiftedandRotatedSchwefelObjective', 'ShiftedandRotatedLunacekBi_RastriginObjective'}
# crossover                                                 P1XO-30  \
# stat                                                         mean
# ShiftedandRotatedRastriginObjective                    887.053985
# ShiftedandRotatedBentCigarObjective            37728978624.471268
# ShiftedandRotatedRosenbrockObjective                  8445.168868
# ShiftedandRotatedLevyObjective                        16691.72544
# ShiftedandRotatedZakharovObjective                40049880.995254
# ShiftedandRotatedSchwefelObjective                    9605.147752
# ShiftedandRotatedLunacekBi_RastriginObjective         1969.453742
#
# crossover                                                 P2XO-30  \
# stat                                                         mean
# ShiftedandRotatedRastriginObjective                    879.575737
# ShiftedandRotatedBentCigarObjective            38880853022.901909
# ShiftedandRotatedRosenbrockObjective                  8569.660751
# ShiftedandRotatedLevyObjective                       15249.240249
# ShiftedandRotatedZakharovObjective                16658198.138837
# ShiftedandRotatedSchwefelObjective                    9629.191171
# ShiftedandRotatedLunacekBi_RastriginObjective         1957.561436
#
# crossover                                     CollectiveCrossover-30
# stat                                                            mean
# ShiftedandRotatedRastriginObjective                       574.798798
# ShiftedandRotatedBentCigarObjective                  165193403.87622
# ShiftedandRotatedRosenbrockObjective                      561.169636
# ShiftedandRotatedLevyObjective                           1033.215446
# ShiftedandRotatedZakharovObjective                      46050.239134
# ShiftedandRotatedSchwefelObjective                        4858.86756
# ShiftedandRotatedLunacekBi_RastriginObjective             863.866444

# %%
# if maxFitness = 120, max fitness count for maxFitness = 30 and 60 won't be shown 
maxFitness = 120
chromoseLength = 15
target_id = 0
target = [
    {
        "folder": "FrontRearCrossover/randomSeed=1", "stats": ["mean", "max fitness count"], "wantFitness": True, 
        "oriResult": getFrontRearCrossoverOriResult("FrontRearCrossover/randomSeed=1"), "index": {'mean': 'mean of fitness evaluation'},
        "crossoverFunctionRename": {"P1XO-"+str(int(maxFitness/chromoseLength)): "Single Point Crossover", 
                              "P2XO-"+str(int(maxFitness/chromoseLength)): "Two Point Crossover", 
                              "UniformCrossover-"+str(int(maxFitness/chromoseLength)): "Uniform Crossover", 
                              "FrontRearCrossover-"+str(int(maxFitness/chromoseLength)): "FrontRear Crossover", 
                              "RingCrossover-"+str(int(maxFitness/chromoseLength)): "Ring Crossover"}
    },
]

folder = target[target_id]["folder"]
stats = target[target_id]["stats"]
wantFitness = target[target_id]["wantFitness"]
oriResult = target[target_id]["oriResult"]
index = target[target_id]["index"]
crossoverFunctionRename=target[target_id]["crossoverFunctionRename"]


# calculate for front-rear crossover
for subdir, dirs, files in os.walk(folder):
    crossovers, benchmarks = getLists(files)
    iterables = [crossovers, stats]
    result = pd.DataFrame(columns = benchmarks, index = pd.MultiIndex.from_product(iterables, names=["crossover", "stat"]))

    files_filtered = [file for file in files if 'FitnessEvaluateCountReachTarget' in file]
    for file in files_filtered:
        crossover = file.split("+")[0]
        benchmark = file.split("+")[1]
        df = pd.read_csv(folder+"/"+file, index_col=False)
        df = fixFormat(df)

        temp_result = {}
        temp_result["mean"] = df["FitnessEvaluateCountReachTarget"].mean()
        temp_result["max"] = df["FitnessEvaluateCountReachTarget"].max()
        temp_result["min"] = df["FitnessEvaluateCountReachTarget"].min()
        temp_result["var"] = df["FitnessEvaluateCountReachTarget"].var()
        temp_result["sum"] = df["FitnessEvaluateCountReachTarget"].sum()

        for stat in stats:
            if stat in temp_result.keys():
                result.loc[crossover, stat][benchmark] = temp_result[stat]
                
    files_filtered = [file for file in files if 'FitnessEvaluateCountReachTarget' not in file]
    for file in files_filtered:
        crossover = file.split("+")[0]
        benchmark = file.split("+")[1].split(".")[0]
        df = pd.read_csv(folder+"/"+file, index_col=False)
        df = fixFormat(df)

        temp_result = {}
        lastGenFx = df[df["Generation"] == df["Generation"].max()]["F(x)"]
        temp_result["max fitness count"] = len(lastGenFx[lastGenFx == maxFitness])
        
        for stat in stats:
            if stat in temp_result.keys():
                result.loc[crossover, stat][benchmark] = temp_result[stat]
    
    filtered_row_index = [k for k in oriResult.index.get_level_values(0).tolist() if '-'+str(int(maxFitness/chromoseLength)) in k]
    for column in result.columns:
        fig, axes = plt.subplots(2, 2)
        a = oriResult[column][np.in1d(oriResult.index.get_level_values(1), stats)]
        a = a[np.in1d(a.index.get_level_values(0), filtered_row_index)].rename(index=index, level=1).rename(crossoverFunctionRename)
        a = a.unstack().plot(kind='bar', subplots=True,sharex=True, title=column, ax=axes[0], figsize=(12,4.8),legend=False)
        
        b = result[column][np.in1d(result.index.get_level_values(0), filtered_row_index)].rename(index=index, level=1).rename(crossoverFunctionRename)
        b = b.unstack().plot(kind='bar', subplots=True,sharex=True,title=column+"(chromosome length="+str(maxFitness)+")", ax=axes[1],legend=False)
        
        plt.figtext(0.06, 0.7, "Original Result", fontsize=12, rotation=90, ha='center', va='center')
        plt.figtext(0.06, 0.3, "Reproduce Result", fontsize=12, rotation=90, ha='center', va='center')
#         print(column)
        plt.savefig(column + "-" + str(maxFitness) + ".jpg", bbox_inches='tight')
    print(crossovers)
    plt.show()
    print(result)
# Out:
# C:\Users\wangl\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes
#   plot_obj.generate()
# {'RingCrossover-2', 'FrontRearCrossover-4', 'FrontRearCrossover-2', 'P1XO-2', 'RingCrossover-4', 'UniformCrossover-4', 'UniformCrossover-8', 'UniformCrossover-2', 'FrontRearCrossover-8', 'P2XO-2', 'P2XO-8', 'P1XO-4', 'RingCrossover-8', 'P1XO-8', 'P2XO-4'}
#                                        OneMaxObjective TrapThreeObjective  \
# crossover            stat
# RingCrossover-2      mean                        303.4             329.11
#                      max fitness count               0                  0
# FrontRearCrossover-4 mean                       581.88              603.0
#                      max fitness count               0                  0
# FrontRearCrossover-2 mean                       303.51             329.99
#                      max fitness count               0                  0
# P1XO-2               mean                      1221.85            9499.04
#                      max fitness count               0                  0
# RingCrossover-4      mean                        556.2             573.66
#                      max fitness count               0                  0
# UniformCrossover-4   mean                      1684.82           14197.13
#                      max fitness count               0                  0
# UniformCrossover-8   mean                      4952.93            15030.0
#                      max fitness count              81                  0
# UniformCrossover-2   mean                       550.96            9963.42
#                      max fitness count               0                  0
# FrontRearCrossover-8 mean                      1154.66             1216.5
#                      max fitness count              96                 92
# P2XO-2               mean                      1521.91           10708.98
#                      max fitness count               0                  0
# P2XO-8               mean                      6236.11           14948.37
#                      max fitness count              68                  2
# P1XO-4               mean                      3050.23           14210.89
#                      max fitness count               0                  0
# RingCrossover-8      mean                      1131.61            1185.26
#                      max fitness count              93                 92
# P1XO-8               mean                      6572.46           14900.67
#                      max fitness count              49                  2
# P2XO-4               mean                      2498.47           13582.61
#                      max fitness count               0                  0
#
#                                        ZeroMaxObjective TrapFiveObjective
# crossover            stat
# RingCrossover-2      mean                        317.68            706.74
#                      max fitness count                0                 0
# FrontRearCrossover-4 mean                        608.16           1384.72
#                      max fitness count                0                 0
# FrontRearCrossover-2 mean                        317.93            733.85
#                      max fitness count                0                 0
# P1XO-2               mean                        776.36          20777.94
#                      max fitness count                0                 0
# RingCrossover-4      mean                        584.41           1354.43
#                      max fitness count                0                 0
# UniformCrossover-4   mean                       1171.07          19551.45
#                      max fitness count                0                 0
# UniformCrossover-8   mean                       2391.36          49359.43
#                      max fitness count               93                40
# UniformCrossover-2   mean                        500.55           4690.85
#                      max fitness count                0                 0
# FrontRearCrossover-8 mean                       1170.84           2649.82
#                      max fitness count               85                99
# P2XO-2               mean                        690.22           12021.7
#                      max fitness count                0                 0
# P2XO-8               mean                       3133.87          74754.32
#                      max fitness count               82                 7
# P1XO-4               mean                       1498.26          42621.74
#                      max fitness count                0                 0
# RingCrossover-8      mean                        1196.9           2566.63
#                      max fitness count               88               100
# P1XO-8               mean                       3690.15          74027.92
#                      max fitness count               69                 8
# P2XO-4               mean                       1394.15          44999.33
#                      max fitness count                0                 0

# %%
def getRingCrossoverOriResult(folder):
    for subdir, dirs, files in os.walk(folder):
        crossovers, benchmarks = getLists(files)
        iterables = [
            ["P1XO", "P2XO", "IntermediateCrossover", "HeuristicCrossover", "ArithmeticCrossover", "RingCrossover"], 
            ["min", "max","mean"]
        ]
        result = pd.DataFrame(columns = benchmarks, index = pd.MultiIndex.from_product(iterables, names=["crossover", "stat"]))
        result["RosenbrocksValleyObjective"] = [
            73.07,269.3,73.08,
            70.07, 390.3, 78.39,
            34.71, 349.2, 34.74,
            29.35, 369.1, 117.5,
            27.08, 260.3, 27.12,
            28.59, 316.1, 32.69,
        ]
        result["AxisParallelHyperEllipsoidObjective"] = [
            70.52, 105.7, 70.52,
            68.63, 94.04, 68.64,
            64.04, 80.4, 64.04,
            0.024, 87.41, 5.706,
            73.71, 89.18, 73.72,
            0.1023, 106.8, 11.73,
        ]
        result["SphereObjective"] = [
            5.732, 7.246, 5.737,
            3.416, 6.511, 3.417,
            6.207, 6.246, 6.208,
            0.011, 8.099, 2.81,
            5.589, 6.389, 5.589,
            0.0027, 6.163, 0.3299
        ]
        result["NormalizedSchwefelObjective"] = [
            -115.7, -29.46, -115.6,
            -115.8, -26.85, -115.4,
            -114.1, -27.91, -114,
            -117.7, -26.1, -117.1,
            -113.2, -27.72, -113.1,
            -117.8, -27.75, -117.7,
        ]
        result["RotatedHyperEllipsoidObjective"] = [
            20.79, 261.7, 37.02,
            15.06, 204.8, 16.22,
            22.86, 59.24, 22.87,
            2.36, 381, 17.58,
            24.37, 47.94, 24.37,
            4.577, 108.2, 18.97,
        ]
        result["GeneralizedRastriginObjective"] = [
            94.69, 241.3, 111.3,
            50.84, 257.7, 52.15,
            122.6, 256.6, 187.3,
            12.68, 173.1, 31.98,
            154, 251.4, 154.1,
            2.669, 232.5, 3.691,
        ]
        return result
    
def getHDGAOriResult(folder):
    for subdir, dirs, files in os.walk(folder):
        crossovers, benchmarks = getLists(files)
        iterables = [
            ["P1XO", "HighDimensionalGeneticAlgorithmToolboxCrossover"], 
            ["min", "mean", "var"]
        ]
        result = pd.DataFrame(columns = benchmarks, index = pd.MultiIndex.from_product(iterables, names=["crossover", "stat"]))
        result["ZakharovObjective"] = [
            8.7426, 40.8791, 297.49,
            2.2244, 13.5011, 56.7825,
        ]
        result["DixonPriceObjective"] = [
            2.4271, 58.9734, 9067.1742,
            0.5538, 6.0133, 120.6263,
        ]
        result["SphereObjective"] = [
            0.055081, 0.2988, 0.066168,
            0.00027559, 0.0071927, 0.00015764,
        ]
        result["ShubertObjective"] = [
            -186.7309, -185.9764, 40.9808,
            -186.7309, -185.9068, 23.069,
        ]
        return result
    
def getCollectiveCrossoverOriResult(folder):
    for subdir, dirs, files in os.walk(folder):
        crossovers, benchmarks = getLists(files)
        iterables = [
            ["CollectiveCrossover-30", "P1XO-30", "P2XO-30", "CollectiveCrossover-50", "P1XO-50", "P2XO-50"], 
            ["mean"]
        ]
        result = pd.DataFrame(columns = benchmarks, index = pd.MultiIndex.from_product(iterables, names=["crossover", "stat"]))
        result["ShiftedandRotatedLunacekBi_RastriginObjective"] = [
            5.75E+07, 1.15E+08, 9.65E+07, 1.76E+08, 3.41E+08, 3.00E+08
        ]
        result["ShiftedandRotatedBentCigarObjective"] = [
            3.79E+13, 4.12E+13, 4.05E+13, 3.61E+14, 4.23E+14, 4.12E+14
        ]
        result["ShiftedandRotatedRastriginObjective"] = [
            2.35E+06, 2.23E+06, 2.43E+06, 5.43E+06, 7.59E+06, 6.66E+06
        ]
        result["ShiftedandRotatedSchwefelObjective"] = [
            1.82E+08, 2.41E+08, 2.34E+08, 5.37E+08, 6.10E+08, 6.56E+08
        ]
        
        result["ShiftedandRotatedRosenbrockObjective"] = [
            6.61E+07, 1.19E+08, 9.90E+07, 2.07E+08, 3.48E+08, 3.32E+08
        ]
        result["ShiftedandRotatedLevyObjective"] = [
            2.91E+09, 3.45E+09, 3.15E+09, 7.06E+09, 7.59E+09, 7.48E+09
        ]
        result["ShiftedandRotatedZakharovObjective"] = [
            1.15E+08, 1.27E+08, 1.31E+08, 2.44E+08, 3.28E+08, 3.02E+08
        ]
        return result
    
def getHybridCrossoverOriResult(folder):
    for subdir, dirs, files in os.walk(folder):
        crossovers, benchmarks = getLists(files)
        iterables = [
            ["P1XO", "P2XO", "UniformCrossover", "HybridCrossover"], 
            ["mean", "max", "min", "con_rate"]
        ]
        result = pd.DataFrame(columns = benchmarks, index = pd.MultiIndex.from_product(iterables, names=["crossover", "stat"]))
        result["SchaffersF6Objective"] = [
            255, 497, 41, 80,
            222, 489, 18, 81,
            247, 461, 25, 79,
            213, 471, 48, 97,
        ]
        result["HansenObjective"] = [
            328, 489, 148, 6,
            317, 335, 304, 3,
            413, 464, 338, 4,
            249, 471, 33, 50,
        ]
        result["RastrigrinObjective"] = [
            307, 466, 75, 29,
            303, 495, 41, 52,
            292, 493, 79, 39,
            99, 457, 18, 98,
        ]
        result["GriewangksObjective"] = [
            280, 481, 50, 43,
            256, 494, 27, 53,
            269, 491, 61, 38,
            162, 489, 19, 97,
        ]
        result["MichalewiczObjective"] = [
            248, 492, 22, 55,
            209, 498, 31, 56,
            215, 469, 33, 59,
            213, 493, 32, 76,
        ]
        result["SphereObjective"] = [
            190, 482, 23, 69,
            194, 464, 18, 86,
            227, 483, 15, 89,
            121, 409, 13, 99,
        ]
        return result
    
def getFrontRearCrossoverOriResult(folder):
    for subdir, dirs, files in os.walk(folder):
        crossovers, benchmarks = getLists(files)
        iterables = [
            [
                'P1XO-2', 'P2XO-2', 'UniformCrossover-2', 'RingCrossover-2', 'FrontRearCrossover-2', 
                'P1XO-4', 'P2XO-4', 'UniformCrossover-4', 'RingCrossover-4', 'FrontRearCrossover-4', 
                'P1XO-8', 'P2XO-8', 'UniformCrossover-8', 'RingCrossover-8', 'FrontRearCrossover-8', 
            ], 
            ["mean", "max fitness count"]
        ]
        result = pd.DataFrame(columns = benchmarks, index = pd.MultiIndex.from_product(iterables, names=["crossover", "stat"]))
        result["OneMaxObjective"] = [
            5106.3, 100,
            5353.5, 100,
            1774.2, 100,
            319.2, 100,
            298.8, 100,
            
            13778.4, 39,
            13788.3, 37,
            10364.4, 67,
            553.8, 100,
            504.6, 100,

            15000, 0,
            15000, 0,
            14984.4, 2,
            878.4, 100,
            835.5, 100,
        ]
        result["TrapThreeObjective"] = [
            14726.4, 2,
            14751, 2,
            14852.7, 1,
            378, 100,
            348.9, 100,

            15000, 0,
            15000, 0,
            15000, 0,
            746.7, 100,
            716.7, 100,

            15000, 0,
            15000, 0,
            15000, 0,
            1412.1, 100,
            1314.3, 100,
        ]
        result["TrapFiveObjective"] = [
            78415.2, 2,
            77626.4, 3,
            80000, 0,
            15968.8, 82,
            1078.4, 100,

            80000, 0,
            80000, 0,
            80000, 0,
            31635.2, 63,
            2058.4, 100,

            80000, 0,
            80000, 0,
            80000, 0,
            35763.2, 58,
            3648, 100,
        ]
        result["ZeroMaxObjective"] = [
            5185.8, 100, 
            5100, 100, 
            1631.4, 100, 
            310.8, 100, 
            293.7, 100, 

            13781.4, 39, 
            13540.8, 39, 
            10086.6, 69, 
            536.4, 100, 
            506.1, 100, 

            15000, 0, 
            15000, 0, 
            14993.7, 1, 
            890.4, 100, 
            838.8, 100, 
        ]
        return result
getRingCrossoverOriResult("RingCrossover")
# getHDGAOriResult("HighDimensionalGeneticAlgorithmToolboxCrossover")
# getCollectiveCrossoverOriResult("CollectiveCrossover")
# getHybridCrossoverOriResult("HybridCrossover")
# getFrontRearCrossoverOriResult("FrontRearCrossover")
# Out:
#                             RosenbrocksValleyObjective  \
# crossover             stat
# P1XO                  min                        73.07
#                       max                       269.30
#                       mean                       73.08
# P2XO                  min                        70.07
#                       max                       390.30
#                       mean                       78.39
# IntermediateCrossover min                        34.71
#                       max                       349.20
#                       mean                       34.74
# HeuristicCrossover    min                        29.35
#                       max                       369.10
#                       mean                      117.50
# ArithmeticCrossover   min                        27.08
#                       max                       260.30
#                       mean                       27.12
# RingCrossover         min                        28.59
#                       max                       316.10
#                       mean                       32.69
#
#                             AxisParallelHyperEllipsoidObjective  \
# crossover             stat
# P1XO                  min                               70.5200
#                       max                              105.7000
#                       mean                              70.5200
# P2XO                  min                               68.6300
#                       max                               94.0400
#                       mean                              68.6400
# IntermediateCrossover min                               64.0400
#                       max                               80.4000
#                       mean                              64.0400
# HeuristicCrossover    min                                0.0240
#                       max                               87.4100
#                       mean                               5.7060
# ArithmeticCrossover   min                               73.7100
#                       max                               89.1800
#                       mean                              73.7200
# RingCrossover         min                                0.1023
#                       max                              106.8000
#                       mean                              11.7300
#
#                             SphereObjective  NormalizedSchwefelObjective  \
# crossover             stat
# P1XO                  min            5.7320                      -115.70
#                       max            7.2460                       -29.46
#                       mean           5.7370                      -115.60
# P2XO                  min            3.4160                      -115.80
#                       max            6.5110                       -26.85
#                       mean           3.4170                      -115.40
# IntermediateCrossover min            6.2070                      -114.10
#                       max            6.2460                       -27.91
#                       mean           6.2080                      -114.00
# HeuristicCrossover    min            0.0110                      -117.70
#                       max            8.0990                       -26.10
#                       mean           2.8100                      -117.10
# ArithmeticCrossover   min            5.5890                      -113.20
#                       max            6.3890                       -27.72
#                       mean           5.5890                      -113.10
# RingCrossover         min            0.0027                      -117.80
#                       max            6.1630                       -27.75
#                       mean           0.3299                      -117.70
#
#                             RotatedHyperEllipsoidObjective  \
# crossover             stat
# P1XO                  min                           20.790
#                       max                          261.700
#                       mean                          37.020
# P2XO                  min                           15.060
#                       max                          204.800
#                       mean                          16.220
# IntermediateCrossover min                           22.860
#                       max                           59.240
#                       mean                          22.870
# HeuristicCrossover    min                            2.360
#                       max                          381.000
#                       mean                          17.580
# ArithmeticCrossover   min                           24.370
#                       max                           47.940
#                       mean                          24.370
# RingCrossover         min                            4.577
#                       max                          108.200
#                       mean                          18.970
#
#                             GeneralizedRastriginObjective
# crossover             stat
# P1XO                  min                          94.690
#                       max                         241.300
#                       mean                        111.300
# P2XO                  min                          50.840
#                       max                         257.700
#                       mean                         52.150
# IntermediateCrossover min                         122.600
#                       max                         256.600
#                       mean                        187.300
# HeuristicCrossover    min                          12.680
#                       max                         173.100
#                       mean                         31.980
# ArithmeticCrossover   min                         154.000
#                       max                         251.400
#                       mean                        154.100
# RingCrossover         min                           2.669
#                       max                         232.500
#                       mean                          3.691

# %%
#thrown
# stats = ["mean", "max", "min", "var", "sum"]
# GeneticAlgorithm.genstep need be be 1
folder = "HybridCrossover/randomSeed=1"
stats = ["mean", "max", "min","con_rate"]
line_stats = ["con_rate"]
wantFitness = False
oriResult = getHybridCrossoverOriResult("HybridCrossover")
index = {"mean": "Avg-con", "max": "Max-con", "min": "Min-con"}
crossoverFunctionRename={"P1XO": "SinglePointCrossover", "P2XO": "TwoPointCrossover"}
crossoverFunctionNameSpacer=r"(?<=\w)([A-Z])"
benchmarkFunctionNameSpacer= r"(?<=\w)([A-Z])"

def round_down(value, decimals):
    with decimal.localcontext() as ctx:
        d = decimal.Decimal(value)
        ctx.rounding = decimal.ROUND_DOWN
        return round(d, decimals)
    
# calculateConvergenceGeneration, if difference smaller than 1.0e-6 then consider no different
def calculateConvergenceGeneration(df):
    result = []
#     repeats = set(df["Repeat"])
    repeats = range(100)
#     generations = sorted(set(df["Generation"]), reverse=True)
    generations = sorted(range(100), reverse=True)
#     print(repeats)
    generations.pop()
    for repeat in repeats:
        gene_count = 0
#         result.append(1)
#         break
        temp = df[df["Repeat"].isin({repeat})]
        for generation in generations:
            old_fx = temp[temp["Generation"].isin({generation-1})]["F(x)"].iloc[0]
            fx = temp[temp["Generation"].isin({generation})]["F(x)"].iloc[0]
            
            if round_down(fx, 6) == round_down(old_fx, 6):
                gene_count = gene_count + 1
            else:
                break
        result.append(generations[0]-gene_count)
    return result

global_mins = {
    "SphereObjective": 0,
    "GeneralizedRastriginObjective": 0,
    "SchaffersF6Objective": 0,
    "GriewangksObjective": 0,
    "HansenObjective": -176.541793,
    "MichalewiczObjective": -1.8013,
}

# calculate absolute range between first and last generation
def calculateConvergenceRate(df, benchmark, minOf="global"):
    def get_min_max_array(array, value):
        array.append(value)
        if len(array) > 2:
            array = [np.min(array), np.max(array)]
        return array
    result = []
    repeats = set(df["Repeat"])
    min_gen = min(df["Generation"])
    max_gen = max(df["Generation"])
    print(min_gen)
    print(max_gen)
    min_gen_fx = []
    max_gen_fx = []
    for repeat in repeats:
        gene_count = 0
        
        temp = df[df["Repeat"].isin({repeat})]
        gen_min_fx = temp[temp["Generation"] == min_gen]["F(x)"].iloc[0]
        min_gen_fx = get_min_max_array(min_gen_fx, gen_min_fx)
        gen_max_fx = temp[temp["Generation"] == max_gen]["F(x)"].iloc[0]
        max_gen_fx = get_min_max_array(max_gen_fx, gen_max_fx)
    if minOf == "global":
        min_gen_fx[0] = global_mins[benchmark]
        max_gen_fx[0] = global_mins[benchmark]
    
    print(min_gen_fx)
    print(max_gen_fx)
    min_gen_fx = abs(min_gen_fx[1] - min_gen_fx[0])
    max_gen_fx = abs(max_gen_fx[1] - max_gen_fx[0])
    print(min_gen_fx)
    print(max_gen_fx)
    if min_gen_fx == 0:
        print(" alr done convergence in start")
        return 0
    else:
        return (1-(max_gen_fx/ min_gen_fx)) * 100
    
for subdir, dirs, files in os.walk(folder):
    crossovers, benchmarks = getLists(files)
    print(crossovers)
    iterables = [crossovers, stats]
    result = pd.DataFrame(columns = benchmarks, index = pd.MultiIndex.from_product(iterables, names=["crossover", "stat"]))

    files = [file for file in files if 'FitnessEvaluateCountReachTarget' not in file]
    for file in files:
        crossover = file.split("+")[0]
        benchmark = file.split("+")[1].split(".")[0]
        df = pd.read_csv(folder+"/"+file, index_col=False)
        df = fixFormat(df)

        temp_result = {}
        convergence = calculateConvergenceGeneration(df)
        temp_result["mean"] = sum(convergence) / len(convergence)
        temp_result["max"] = np.max(convergence)
        temp_result["min"] = np.min(convergence)
        temp_result["var"] = np.var(convergence)
        temp_result["sum"] = sum(convergence)
        temp_result["con_rate"] = calculateConvergenceRate(df, benchmark, "own")
#         if "con_rate_with_own" in stats:
#             temp_result["con_rate_with_own"] = calculateConvergenceRate(df, benchmark, "own")
#         if "con_rate_with_global_min" in stats:
#             temp_result["con_rate_with_global_min"] = calculateConvergenceRate(df, benchmark, "global")

        for stat in stats:
            result.loc[crossover, stat][benchmark] = temp_result[stat]

    for column in result.columns:
        fig, axes = plt.subplots(1, 2)
#         [np.in1d(oriResult.index.get_level_values(1), stats)]
        a = oriResult[column].rename(index=index, level=1).rename(crossoverFunctionRename).rename(lambda s: re.sub(crossoverFunctionNameSpacer, r" \1",s))
        a = a.unstack().plot(kind='bar', title='Original result of\n'+re.sub(benchmarkFunctionNameSpacer, r" \1",titleFixer(column.replace("Objective", "Function"),3)), ax=axes[0],figsize=(14,4.8), secondary_y=["con_rate"])
        a.set_ylabel("Fitness value" if wantFitness else "f(x)")
        
        b = result[column].rename(index=index, level=1).rename(lambda s: re.sub(crossoverFunctionNameSpacer, r" \1",s))
        b = b.unstack().plot(kind='bar', title='Original result of\n'+re.sub(benchmarkFunctionNameSpacer, r" \1",titleFixer(column.replace("Objective", "Function"),3)), ax=axes[1], secondary_y=["con_rate"])
        b.set_ylabel("Fitness value" if wantFitness else "f(x)")
#         plt.savefig(column + ".jpg", bbox_inches='tight')
    plt.show()
    print(result)
